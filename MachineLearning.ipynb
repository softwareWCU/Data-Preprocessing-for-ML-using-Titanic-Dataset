# %% [markdown]
# <a href="https://colab.research.google.com/github/chere-collab/Data-Preprocessing-for-MLL-using-Titanic-Dataset/blob/main/MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://chere-collab: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e@github.com/chere-collab/Data-Preprocessing-for-ML-using-Titanic-Dataset.git
# Out:
# Cloning into 'Data-Preprocessing-for-ML-using-Titanic-Dataset'...
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/chere-collab/Data-Preprocessing-for-ML-using-Titanic-Dataset.git/'
