# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/softwareWCU/Data-Preprocessing-for-ML-using-Titanic-Dataset/main/titanic2.csv')

# %%
df
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 904          245         0      3
# 905          345         0      2
# 906          854         1      1
# 907          622         1      1
# 908          654         1      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived         Age       SibSp       Parch        Fare
# count   909.000000  909.000000  909.000000  909.000000  909.000000  909.000000
# mean    446.040704    0.387239   29.252200    0.522552    0.380638   30.968156
# std     257.212740    0.487387   12.889112    1.098050    0.802185   46.446184
# min       1.000000    0.000000    0.420000    0.000000    0.000000    0.000000
# 25%     224.000000    0.000000   22.000000    0.000000    0.000000    7.925000
# 50%     445.000000    0.000000   28.000000    0.000000    0.000000   14.000000
# 75%     669.000000    1.000000   35.000000    1.000000    0.000000   30.500000
# max     891.000000    1.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            199
# SibSp            0
# Parch            0
# Ticket           0
# Fare            18
# Embarked         2
# dtype: int64

# %%
df['Age']=df['Age'].fillna(df['Age'].median())
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])
df['Fare']=df['Fare'].fillna(df['Fare'].mode())

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare           18
# Embarked        0
# dtype: int64

# %%
df['Fare']=df['Fare'].fillna(df['Fare'].mode()[0])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
num_cols = ['age']
for col in num_cols:
  Q1 = df[col].quantile(0.25)
  Q3 = df [col].quantile(0.75)
  IQR =Q3 -Q1
  lower_bound =
# Out:
#   File "/tmp/ipython-input-1385329019.py", line 6
#     lower_bound =
#                   ^
# SyntaxError: invalid syntax

# %%
df_copy = df.copy()

# %%
df.duplicated().sum()
# Out:
# np.int64(10)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated();

# %%
df['Embarked'] = df['Embarked'].replace('Cherbourg', 'C').replace('Southampton', 'S')
df['Sex'] = df['Sex'].str.lower()

# %%
df
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 904          245         0      3
# 905          345         0      2
# 906          854         1      1
# 907          622         1      1
# 908          654         1      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Task
# Use KNN to predict the `Survived` column.

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## Prepare data
#
# ### Subtask:
# Select features and target variable, handle categorical variables, and split the data into training and testing sets.

# %% [markdown]
# **Reasoning**:
# Define features and target, handle categorical variables with one-hot encoding, and split the data.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/softwareWCU/Data-Preprocessing-for-ML-using-Titanic-Dataset/main/titanic2.csv')

# Applying previous preprocessing steps to ensure df is correctly defined
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df['Fare'] = df['Fare'].fillna(df['Fare'].mode()[0])
df.drop_duplicates(inplace=True)
df['Embarked'] = df['Embarked'].replace('Cherbourg', 'C').replace('Southampton', 'S')
df['Sex'] = df['Sex'].str.lower()

# Original content of the cell
df.head()
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 899 entries, 0 to 907
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  899 non-null    int64
#  1   Survived     899 non-null    int64
#  2   Pclass       899 non-null    object
#  3   Name         899 non-null    object
#  4   Sex          899 non-null    object
#  5   Age          899 non-null    float64
#  6   SibSp        899 non-null    int64
#  7   Parch        899 non-null    int64
#  8   Ticket       899 non-null    object
#  9   Fare         899 non-null    float64
#  10  Cabin        206 non-null    object
#  11  Embarked     899 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 91.3+ KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Drop columns that are not useful for prediction
df_processed = df.drop(['Name', 'Ticket', 'Cabin', 'PassengerId'], axis=1)

# Define features (X) and target (y)
X = df_processed.drop('Survived', axis=1)
y = df_processed['Survived']

# Identify categorical and numerical features
categorical_features = ['Pclass', 'Sex', 'Embarked']
numerical_features = ['Age', 'SibSp', 'Parch', 'Fare']

# Create a column transformer for one-hot encoding categorical features
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ],
    remainder='passthrough' # Keep numerical features as they are for now
)

# Apply the preprocessor
X_processed = preprocessor.fit_transform(X)

# Get feature names after one-hot encoding for better interpretability (optional, but good practice)
# This part can be tricky with remainder='passthrough', especially with sparse matrices
# For now, we will just proceed with the processed array

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (719, 20)
# Shape of X_test: (180, 20)
# Shape of y_train: (719,)
# Shape of y_test: (180,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler(with_mean=False)  # with_mean=False since we used OneHotEncoder (sparse matrix)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

y_pred = knn.predict(X_test_scaled)

print("✅ KNN Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# ✅ KNN Accuracy: 0.7777777777777778
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       112
#            1       0.74      0.63      0.68        68
#
#     accuracy                           0.78       180
#    macro avg       0.77      0.75      0.76       180
# weighted avg       0.77      0.78      0.77       180
#
#
# Confusion Matrix:
#  [[97 15]
#  [25 43]]

# %%
best_score = 0
best_k = 1

for k in range(1, 21):
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_train_scaled, y_train)
    score = model.score(X_test_scaled, y_test)
    print(f"k={k}, Accuracy={score:.4f}")
    if score > best_score:
        best_score = score
        best_k = k

print(f"\nBest k = {best_k} with accuracy = {best_score:.4f}")
# Out:
# k=1, Accuracy=0.7833
# k=2, Accuracy=0.7722
# k=3, Accuracy=0.8222
# k=4, Accuracy=0.7722
# k=5, Accuracy=0.8222
# k=6, Accuracy=0.7833
# k=7, Accuracy=0.7778
# k=8, Accuracy=0.7722
# k=9, Accuracy=0.7444
# k=10, Accuracy=0.7556
# k=11, Accuracy=0.7444
# k=12, Accuracy=0.7722
# k=13, Accuracy=0.7722
# k=14, Accuracy=0.7778
# k=15, Accuracy=0.7667
# k=16, Accuracy=0.7889
# k=17, Accuracy=0.7722
# k=18, Accuracy=0.7889
# k=19, Accuracy=0.8000
# k=20, Accuracy=0.7889
#
# Best k = 3 with accuracy = 0.8222

# %%
import matplotlib.pyplot as plt

k_values = list(range(1, 21))
accuracies = [
    0.7833, 0.7722, 0.8222, 0.7722, 0.8222, 0.7833,
    0.7778, 0.7722, 0.7444, 0.7556, 0.7444, 0.7722,
    0.7722, 0.7778, 0.7667, 0.7889, 0.7722, 0.7889,
    0.8000, 0.7889
]

plt.figure(figsize=(8,4))
plt.plot(k_values, accuracies, marker='o', color='blue')
plt.title("KNN Accuracy vs K")
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()
